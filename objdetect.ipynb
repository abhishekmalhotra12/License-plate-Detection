# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import os 
import cv2

# %%
df = pd.read_csv('labels.csv')
df.head()
# Out:
#           filepath  xmin  xmax  ymin  ymax
# 0  ./images/15.xml   474   834   599   670
# 1  ./images/01.xml   410   651   387   460
# 2  ./images/03.xml    73   131   115   129
# 3  ./images/02.xml   186   236   123   134
# 4  ./images/12.xml   407   649   387   467

# %%
import xml.etree.ElementTree as xet

# %%
filename = df['filepath'][1]
filename
# Out:
# './images/01.xml'

# %%
def getFilename(filename):
    filename_image = xet.parse(filename).getroot().find('filename').text
    filepath_image = os.path.join('./images',filename_image)
    return filepath_image

# %%
getFilename(filename)
# Out:
# './images/01.jpg'

# %%
image_path = list(df['filepath'].apply(getFilename))
image_path
# Out:
# ['./images/15.jpg',
#  './images/01.jpg',
#  './images/03.jpeg',
#  './images/02.jpeg',
#  './images/12.jpg',
#  './images/06.jpeg',
#  './images/13.jpg',
#  './images/05.jpg',
#  './images/11.jpg',
#  './images/10.jpg',
#  './images/04.jpeg',
#  './images/09.jpeg',
#  './images/08.jpeg',
#  './images/14.jpg.webp']

# %%
####verify image and output

# %%
file_path = image_path[1]
#file_path

# %%
img = cv2.imread(file_path) 

cv2.rectangle(img,(410,387),(651,460),(0,255,0),3)
cv2.namedWindow('example',cv2.WINDOW_NORMAL)
cv2.imshow('example',img)
cv2.waitKey(0)
cv2.destroyAllwindows()
# Out:
# 1   HIToolbox                           0x000000018cec45c8 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 120
# 2   HIToolbox                           0x000000018cec4188 _ZN15MenuBarInstance14EnableAutoShowEv + 60
# 3   HIToolbox                           0x000000018ce318bc _ZN15MenuBarInstance21UpdateAggregateUIModeE21MenuBarAnimationStylehhh + 1184
# 4   HIToolbox                           0x000000018cec4004 _ZN15MenuBarInstance19SetFullScreenUIModeEjj + 180
# 5   AppKit                              0x0000000186cb3d1c -[NSApplication _setPresentationOptions:instance:flags:] + 956
# 6   AppKit                              0x0000000186b49928 -[NSApplication _updateFullScreenPresentationOptionsForInstance:] + 404
# 7   CoreFoundation                      0x0000000183766560 __CFNOTIFICATIONCENTER_IS_CALLING_OUT_TO_AN_OBSERVER__ + 148
# 8   CoreFoundation                      0x0000000183804044 ___CFXRegistrationPost_block_invoke + 88
# 9   CoreFoundation                      0x0000000183803f8c _CFXRegistrationPost + 440
# 10  CoreFoundation                      0x0000000183737b64 _CFXNotificationPost + 708
# 11  Foundation                          0x000000018462738c -[NSNotificationCenter postNotificationName:object:userInfo:] + 88
# 12  AppKit                              0x0000000186cb42a0 spacesNotificationHandler + 96
# 13  SkyLight                            0x00000001883a1214 _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 896
# 14  SkyLight                            0x000000018839fe10 CGSSnarfAndDispatchDatagrams + 808
# 15  SkyLight                            0x00000001886c7a9c SLSGetNextEventRecordInternal + 344
# 16  SkyLight                            0x00000001884c8fb0 SLEventCreateNextEvent + 16
# 17  HIToolbox                           0x000000018ce5cb58 _ZL38PullEventsFromWindowServerOnConnectionjhP17__CFMachPortBoost + 60
# 18  HIToolbox                           0x000000018ce5cae0 _ZL14MessageHandlerP12__CFMachPortPvlS1_ + 60
# 19  CoreFoundation                      0x00000001837a1410 __CFMachPortPerform + 260
# 20  CoreFoundation                      0x0000000183771f98 __CFRUNLOOP_IS_CALLING_OUT_TO_A_SOURCE1_PERFORM_FUNCTION__ + 60
# 21  CoreFoundation                      0x0000000183771eb8 __CFRunLoopDoSource1 + 520
# 22  CoreFoundation                      0x00000001837708a4 __CFRunLoopRun + 2264
# 23  CoreFoundation                      0x000000018376f878 CFRunLoopRunSpecific + 612
# 24  HIToolbox                           0x000000018ce4ffa0 RunCurrentEventLoopInMode + 292
# 25  HIToolbox                           0x000000018ce4fc30 ReceiveNextEventCommon + 236
# 26  HIToolbox                           0x000000018ce4fb2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 27  AppKit                              0x00000001869f5838 _DPSNextEvent + 632
# 28  AppKit                              0x00000001869f49c8 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 29  cv2.abi3.so                         0x0000000164706e04 cvWaitKey + 560
# 30  cv2.abi3.so                         0x0000000164700e64 _ZN2cv9waitKeyExEi + 168
# 31  cv2.abi3.so                         0x0000000164700f5c _ZN2cv7waitKeyEi + 48
# 32  cv2.abi3.so                         0x0000000163cc98f0 _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 33  python3.10                          0x0000000104579648 cfunction_call + 60
# 34  python3.10                          0x0000000104637334 _PyEval_EvalFrameDefault + 59080
# 35  python3.10                          0x0000000104626f60 _PyEval_Vector + 532
# 36  python3.10                          0x0000000104621a14 builtin_exec + 308
# 37  python3.10                          0x000000010457a44c cfunction_vectorcall_FASTCALL + 88
# 38  python3.10                          0x0000000104651a48 call_function + 148
# 39  python3.10                          0x000000010462a95c _PyEval_EvalFrameDefault + 7408
# 40  python3.10                          0x0000000104535e64 gen_send_ex2 + 220
# 41  python3.10                          0x0000000104635858 _PyEval_EvalFrameDefault + 52204
# 42  python3.10                          0x0000000104535e64 gen_send_ex2 + 220
# 43  python3.10                          0x0000000104635858 _PyEval_EvalFrameDefault + 52204
# 44  python3.10                          0x0000000104535e64 gen_send_ex2 + 220
# 45  python3.10                          0x0000000104536488 gen_send + 52
# 46  python3.10                          0x000000010452a908 method_vectorcall_O + 112
# 47  python3.10                          0x00000001046311c4 _PyEval_EvalFrameDefault + 34136
# 48  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 49  python3.10                          0x0000000104651a48 call_function + 148
# 50  python3.10                          0x000000010462a95c _PyEval_EvalFrameDefault + 7408
# 51  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 52  python3.10                          0x00000001046311c4 _PyEval_EvalFrameDefault + 34136
# 53  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 54  python3.10                          0x00000001045203b0 method_vectorcall + 124
# 55  python3.10                          0x0000000104630e2c _PyEval_EvalFrameDefault + 33216
# 56  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 57  python3.10                          0x00000001045203b0 method_vectorcall + 124
# 58  python3.10                          0x0000000104651a48 call_function + 148
# 59  python3.10                          0x000000010462a86c _PyEval_EvalFrameDefault + 7168
# 60  python3.10                          0x0000000104535e64 gen_send_ex2 + 220
# 61  python3.10                          0x0000000104635858 _PyEval_EvalFrameDefault + 52204
# 62  python3.10                          0x0000000104535e64 gen_send_ex2 + 220
# 63  python3.10                          0x0000000104635858 _PyEval_EvalFrameDefault + 52204
# 64  python3.10                          0x0000000104535e64 gen_send_ex2 + 220
# 65  python3.10                          0x0000000104635858 _PyEval_EvalFrameDefault + 52204
# 66  python3.10                          0x0000000104535e64 gen_send_ex2 + 220
# 67  python3.10                          0x0000000104635858 _PyEval_EvalFrameDefault + 52204
# 68  python3.10                          0x0000000104535e64 gen_send_ex2 + 220
# 69  _asyncio.cpython-310-darwin.so      0x00000001061dc54c task_step_impl + 440
# 70  _asyncio.cpython-310-darwin.so      0x00000001061dc304 task_step + 68
# 71  _asyncio.cpython-310-darwin.so      0x00000001061dce08 task_wakeup + 136
# 72  python3.10                          0x000000010457a13c cfunction_vectorcall_O + 100
# 73  python3.10                          0x000000010466a2cc _PyObject_VectorcallTstate.4686 + 88
# 74  python3.10                          0x000000010466a190 context_run + 92
# 75  python3.10                          0x000000010457a39c cfunction_vectorcall_FASTCALL_KEYWORDS + 84
# 76  python3.10                          0x000000010463467c _PyEval_EvalFrameDefault + 47632
# 77  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 78  python3.10                          0x00000001046311c4 _PyEval_EvalFrameDefault + 34136
# 79  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 80  python3.10                          0x00000001046311c4 _PyEval_EvalFrameDefault + 34136
# 81  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 82  python3.10                          0x00000001046311c4 _PyEval_EvalFrameDefault + 34136
# 83  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 84  python3.10                          0x00000001046311c4 _PyEval_EvalFrameDefault + 34136
# 85  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 86  python3.10                          0x00000001046311c4 _PyEval_EvalFrameDefault + 34136
# 87  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 88  python3.10                          0x00000001045203b0 method_vectorcall + 124
# 89  python3.10                          0x000000010463296c _PyEval_EvalFrameDefault + 40192
# 90  python3.10                          0x0000000104626f60 _PyEval_Vector + 532
# 91  python3.10                          0x0000000104621a14 builtin_exec + 308
# 92  python3.10                          0x000000010457a44c cfunction_vectorcall_FASTCALL + 88
# 93  python3.10                          0x0000000104651a48 call_function + 148
# 94  python3.10                          0x000000010462a95c _PyEval_EvalFrameDefault + 7408
# 95  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 96  python3.10                          0x0000000104651a48 call_function + 148
# 97  python3.10                          0x000000010462a95c _PyEval_EvalFrameDefault + 7408
# 98  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 99  python3.10                          0x00000001046c2f38 pymain_run_module + 212
# 100 python3.10                          0x00000001046c2920 pymain_run_python + 188
# 101 python3.10                          0x00000001046c280c Py_RunMain + 40
# 102 python3.10                          0x00000001044bbb58 main + 56
# 103 dyld                                0x0000000183367e50 start + 2544
# 1   HIToolbox                           0x000000018ce4f90c _ZN15MenuBarInstance22RemoveAutoShowObserverEv + 44
# 2   HIToolbox                           0x000000018ce8e478 _ZL17BroadcastInternaljPvh + 184
# 3   SkyLight                            0x00000001883a1214 _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 896
# 4   SkyLight                            0x000000018839fe10 CGSSnarfAndDispatchDatagrams + 808
# 5   SkyLight                            0x00000001886c7a9c SLSGetNextEventRecordInternal + 344
# 6   SkyLight                            0x00000001884c8fb0 SLEventCreateNextEvent + 16
# 7   HIToolbox                           0x000000018ce5cb58 _ZL38PullEventsFromWindowServerOnConnectionjhP17__CFMachPortBoost + 60
# 8   HIToolbox                           0x000000018ce5cae0 _ZL14MessageHandlerP12__CFMachPortPvlS1_ + 60
# 9   CoreFoundation                      0x00000001837a1410 __CFMachPortPerform + 260
# 10  CoreFoundation                      0x0000000183771f98 __CFRUNLOOP_IS_CALLING_OUT_TO_A_SOURCE1_PERFORM_FUNCTION__ + 60
# 11  CoreFoundation                      0x0000000183771eb8 __CFRunLoopDoSource1 + 520
# 12  CoreFoundation                      0x00000001837708a4 __CFRunLoopRun + 2264
# 13  CoreFoundation                      0x000000018376f878 CFRunLoopRunSpecific + 612
# 14  HIToolbox                           0x000000018ce4ffa0 RunCurrentEventLoopInMode + 292
# 15  HIToolbox                           0x000000018ce4fc30 ReceiveNextEventCommon + 236
# 16  HIToolbox                           0x000000018ce4fb2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 17  AppKit                              0x00000001869f5838 _DPSNextEvent + 632
# 18  AppKit                              0x00000001869f49c8 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 19  cv2.abi3.so                         0x0000000164706e04 cvWaitKey + 560
# 20  cv2.abi3.so                         0x0000000164700e64 _ZN2cv9waitKeyExEi + 168
# 21  cv2.abi3.so                         0x0000000164700f5c _ZN2cv7waitKeyEi + 48
# 22  cv2.abi3.so                         0x0000000163cc98f0 _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 23  python3.10                          0x0000000104579648 cfunction_call + 60
# 24  python3.10                          0x0000000104637334 _PyEval_EvalFrameDefault + 59080
# 25  python3.10                          0x0000000104626f60 _PyEval_Vector + 532
# 26  python3.10                          0x0000000104621a14 builtin_exec + 308
# 27  python3.10                          0x000000010457a44c cfunction_vectorcall_FASTCALL + 88
# 28  python3.10                          0x0000000104651a48 call_function + 148
# 29  python3.10                          0x000000010462a95c _PyEval_EvalFrameDefault + 7408
# 30  python3.10                          0x0000000104535e64 gen_send_ex2 + 220
# 31  python3.10                          0x0000000104635858 _PyEval_EvalFrameDefault + 52204
# 32  python3.10                          0x0000000104535e64 gen_send_ex2 + 220
# 33  python3.10                          0x0000000104635858 _PyEval_EvalFrameDefault + 52204
# 34  python3.10                          0x0000000104535e64 gen_send_ex2 + 220
# 35  python3.10                          0x0000000104536488 gen_send + 52
# 36  python3.10                          0x000000010452a908 method_vectorcall_O + 112
# 37  python3.10                          0x00000001046311c4 _PyEval_EvalFrameDefault + 34136
# 38  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 39  python3.10                          0x0000000104651a48 call_function + 148
# 40  python3.10                          0x000000010462a95c _PyEval_EvalFrameDefault + 7408
# 41  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 42  python3.10                          0x00000001046311c4 _PyEval_EvalFrameDefault + 34136
# 43  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 44  python3.10                          0x00000001045203b0 method_vectorcall + 124
# 45  python3.10                          0x0000000104630e2c _PyEval_EvalFrameDefault + 33216
# 46  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 47  python3.10                          0x00000001045203b0 method_vectorcall + 124
# 48  python3.10                          0x0000000104651a48 call_function + 148
# 49  python3.10                          0x000000010462a86c _PyEval_EvalFrameDefault + 7168
# 50  python3.10                          0x0000000104535e64 gen_send_ex2 + 220
# 51  python3.10                          0x0000000104635858 _PyEval_EvalFrameDefault + 52204
# 52  python3.10                          0x0000000104535e64 gen_send_ex2 + 220
# 53  python3.10                          0x0000000104635858 _PyEval_EvalFrameDefault + 52204
# 54  python3.10                          0x0000000104535e64 gen_send_ex2 + 220
# 55  python3.10                          0x0000000104635858 _PyEval_EvalFrameDefault + 52204
# 56  python3.10                          0x0000000104535e64 gen_send_ex2 + 220
# 57  python3.10                          0x0000000104635858 _PyEval_EvalFrameDefault + 52204
# 58  python3.10                          0x0000000104535e64 gen_send_ex2 + 220
# 59  _asyncio.cpython-310-darwin.so      0x00000001061dc54c task_step_impl + 440
# 60  _asyncio.cpython-310-darwin.so      0x00000001061dc304 task_step + 68
# 61  _asyncio.cpython-310-darwin.so      0x00000001061dce08 task_wakeup + 136
# 62  python3.10                          0x000000010457a13c cfunction_vectorcall_O + 100
# 63  python3.10                          0x000000010466a2cc _PyObject_VectorcallTstate.4686 + 88
# 64  python3.10                          0x000000010466a190 context_run + 92
# 65  python3.10                          0x000000010457a39c cfunction_vectorcall_FASTCALL_KEYWORDS + 84
# 66  python3.10                          0x000000010463467c _PyEval_EvalFrameDefault + 47632
# 67  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 68  python3.10                          0x00000001046311c4 _PyEval_EvalFrameDefault + 34136
# 69  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 70  python3.10                          0x00000001046311c4 _PyEval_EvalFrameDefault + 34136
# 71  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 72  python3.10                          0x00000001046311c4 _PyEval_EvalFrameDefault + 34136
# 73  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 74  python3.10                          0x00000001046311c4 _PyEval_EvalFrameDefault + 34136
# 75  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 76  python3.10                          0x00000001046311c4 _PyEval_EvalFrameDefault + 34136
# 77  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 78  python3.10                          0x00000001045203b0 method_vectorcall + 124
# 79  python3.10                          0x000000010463296c _PyEval_EvalFrameDefault + 40192
# 80  python3.10                          0x0000000104626f60 _PyEval_Vector + 532
# 81  python3.10                          0x0000000104621a14 builtin_exec + 308
# 82  python3.10                          0x000000010457a44c cfunction_vectorcall_FASTCALL + 88
# 83  python3.10                          0x0000000104651a48 call_function + 148
# 84  python3.10                          0x000000010462a95c _PyEval_EvalFrameDefault + 7408
# 85  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 86  python3.10                          0x0000000104651a48 call_function + 148
# 87  python3.10                          0x000000010462a95c _PyEval_EvalFrameDefault + 7408
# 88  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 89  python3.10                          0x00000001046c2f38 pymain_run_module + 212
# 90  python3.10                          0x00000001046c2920 pymain_run_python + 188
# 91  python3.10                          0x00000001046c280c Py_RunMain + 40
# 92  python3.10                          0x00000001044bbb58 main + 56
# 93  dyld                                0x0000000183367e50 start + 2544
# 1   HIToolbox                           0x000000018cec45c8 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 120
# 2   HIToolbox                           0x000000018ce8e478 _ZL17BroadcastInternaljPvh + 184
# 3   SkyLight                            0x00000001883a1214 _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 896
# 4   SkyLight                            0x000000018839fe10 CGSSnarfAndDispatchDatagrams + 808
# 5   SkyLight                            0x00000001886c7a9c SLSGetNextEventRecordInternal + 344
# 6   SkyLight                            0x00000001884c8fb0 SLEventCreateNextEvent + 16
# 7   HIToolbox                           0x000000018ce5cb58 _ZL38PullEventsFromWindowServerOnConnectionjhP17__CFMachPortBoost + 60
# 8   HIToolbox                           0x000000018ce5cae0 _ZL14MessageHandlerP12__CFMachPortPvlS1_ + 60
# 9   CoreFoundation                      0x00000001837a1410 __CFMachPortPerform + 260
# 10  CoreFoundation                      0x0000000183771f98 __CFRUNLOOP_IS_CALLING_OUT_TO_A_SOURCE1_PERFORM_FUNCTION__ + 60
# 11  CoreFoundation                      0x0000000183771eb8 __CFRunLoopDoSource1 + 520
# 12  CoreFoundation                      0x00000001837708a4 __CFRunLoopRun + 2264
# 13  CoreFoundation                      0x000000018376f878 CFRunLoopRunSpecific + 612
# 14  HIToolbox                           0x000000018ce4ffa0 RunCurrentEventLoopInMode + 292
# 15  HIToolbox                           0x000000018ce4fc30 ReceiveNextEventCommon + 236
# 16  HIToolbox                           0x000000018ce4fb2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 17  AppKit                              0x00000001869f5838 _DPSNextEvent + 632
# 18  AppKit                              0x00000001869f49c8 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 19  cv2.abi3.so                         0x0000000164706e04 cvWaitKey + 560
# 20  cv2.abi3.so                         0x0000000164700e64 _ZN2cv9waitKeyExEi + 168
# 21  cv2.abi3.so                         0x0000000164700f5c _ZN2cv7waitKeyEi + 48
# 22  cv2.abi3.so                         0x0000000163cc98f0 _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 23  python3.10                          0x0000000104579648 cfunction_call + 60
# 24  python3.10                          0x0000000104637334 _PyEval_EvalFrameDefault + 59080
# 25  python3.10                          0x0000000104626f60 _PyEval_Vector + 532
# 26  python3.10                          0x0000000104621a14 builtin_exec + 308
# 27  python3.10                          0x000000010457a44c cfunction_vectorcall_FASTCALL + 88
# 28  python3.10                          0x0000000104651a48 call_function + 148
# 29  python3.10                          0x000000010462a95c _PyEval_EvalFrameDefault + 7408
# 30  python3.10                          0x0000000104535e64 gen_send_ex2 + 220
# 31  python3.10                          0x0000000104635858 _PyEval_EvalFrameDefault + 52204
# 32  python3.10                          0x0000000104535e64 gen_send_ex2 + 220
# 33  python3.10                          0x0000000104635858 _PyEval_EvalFrameDefault + 52204
# 34  python3.10                          0x0000000104535e64 gen_send_ex2 + 220
# 35  python3.10                          0x0000000104536488 gen_send + 52
# 36  python3.10                          0x000000010452a908 method_vectorcall_O + 112
# 37  python3.10                          0x00000001046311c4 _PyEval_EvalFrameDefault + 34136
# 38  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 39  python3.10                          0x0000000104651a48 call_function + 148
# 40  python3.10                          0x000000010462a95c _PyEval_EvalFrameDefault + 7408
# 41  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 42  python3.10                          0x00000001046311c4 _PyEval_EvalFrameDefault + 34136
# 43  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 44  python3.10                          0x00000001045203b0 method_vectorcall + 124
# 45  python3.10                          0x0000000104630e2c _PyEval_EvalFrameDefault + 33216
# 46  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 47  python3.10                          0x00000001045203b0 method_vectorcall + 124
# 48  python3.10                          0x0000000104651a48 call_function + 148
# 49  python3.10                          0x000000010462a86c _PyEval_EvalFrameDefault + 7168
# 50  python3.10                          0x0000000104535e64 gen_send_ex2 + 220
# 51  python3.10                          0x0000000104635858 _PyEval_EvalFrameDefault + 52204
# 52  python3.10                          0x0000000104535e64 gen_send_ex2 + 220
# 53  python3.10                          0x0000000104635858 _PyEval_EvalFrameDefault + 52204
# 54  python3.10                          0x0000000104535e64 gen_send_ex2 + 220
# 55  python3.10                          0x0000000104635858 _PyEval_EvalFrameDefault + 52204
# 56  python3.10                          0x0000000104535e64 gen_send_ex2 + 220
# 57  python3.10                          0x0000000104635858 _PyEval_EvalFrameDefault + 52204
# 58  python3.10                          0x0000000104535e64 gen_send_ex2 + 220
# 59  _asyncio.cpython-310-darwin.so      0x00000001061dc54c task_step_impl + 440
# 60  _asyncio.cpython-310-darwin.so      0x00000001061dc304 task_step + 68
# 61  _asyncio.cpython-310-darwin.so      0x00000001061dce08 task_wakeup + 136
# 62  python3.10                          0x000000010457a13c cfunction_vectorcall_O + 100
# 63  python3.10                          0x000000010466a2cc _PyObject_VectorcallTstate.4686 + 88
# 64  python3.10                          0x000000010466a190 context_run + 92
# 65  python3.10                          0x000000010457a39c cfunction_vectorcall_FASTCALL_KEYWORDS + 84
# 66  python3.10                          0x000000010463467c _PyEval_EvalFrameDefault + 47632
# 67  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 68  python3.10                          0x00000001046311c4 _PyEval_EvalFrameDefault + 34136
# 69  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 70  python3.10                          0x00000001046311c4 _PyEval_EvalFrameDefault + 34136
# 71  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 72  python3.10                          0x00000001046311c4 _PyEval_EvalFrameDefault + 34136
# 73  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 74  python3.10                          0x00000001046311c4 _PyEval_EvalFrameDefault + 34136
# 75  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 76  python3.10                          0x00000001046311c4 _PyEval_EvalFrameDefault + 34136
# 77  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 78  python3.10                          0x00000001045203b0 method_vectorcall + 124
# 79  python3.10                          0x000000010463296c _PyEval_EvalFrameDefault + 40192
# 80  python3.10                          0x0000000104626f60 _PyEval_Vector + 532
# 81  python3.10                          0x0000000104621a14 builtin_exec + 308
# 82  python3.10                          0x000000010457a44c cfunction_vectorcall_FASTCALL + 88
# 83  python3.10                          0x0000000104651a48 call_function + 148
# 84  python3.10                          0x000000010462a95c _PyEval_EvalFrameDefault + 7408
# 85  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 86  python3.10                          0x0000000104651a48 call_function + 148
# 87  python3.10                          0x000000010462a95c _PyEval_EvalFrameDefault + 7408
# 88  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 89  python3.10                          0x00000001046c2f38 pymain_run_module + 212
# 90  python3.10                          0x00000001046c2920 pymain_run_python + 188
# 91  python3.10                          0x00000001046c280c Py_RunMain + 40
# 92  python3.10                          0x00000001044bbb58 main + 56
# 93  dyld                                0x0000000183367e50 start + 2544
# 1   HIToolbox                           0x000000018ce4f90c _ZN15MenuBarInstance22RemoveAutoShowObserverEv + 44
# 2   HIToolbox                           0x000000018cec4fbc _ZN15MenuBarInstance15DisableAutoShowEv + 36
# 3   HIToolbox                           0x000000018cec50b0 _ZN15MenuBarInstanceD2Ev + 128
# 4   HIToolbox                           0x000000018cec4ee0 _ZN15MenuBarInstance7ReleaseEv + 56
# 5   AppKit                              0x00000001870514dc -[NSHIPresentationInstance discard] + 228
# 6   AppKit                              0x00000001874108b4 -[_NSFullScreenSpace(PresentationInstance) discardPresentationInstance] + 32
# 7   AppKit                              0x000000018741090c -[_NSFullScreenSpace(PresentationInstance) activateFullScreenPresentationOptions] + 64
# 8   AppKit                              0x000000018726a968 -[_NSExitFullScreenTransitionController _doSucceededToExitFullScreen] + 40
# 9   AppKit                              0x000000018726b440 __63-[_NSExitFullScreenTransitionController _performExitFullScreen]_block_invoke + 236
# 10  libxpc.dylib                        0x000000018340242c _xpc_connection_reply_callout + 124
# 11  libxpc.dylib                        0x000000018340231c _xpc_connection_call_reply_async + 88
# 12  libdispatch.dylib                   0x000000018350a584 _dispatch_client_callout3 + 20
# 13  libdispatch.dylib                   0x0000000183528710 _dispatch_mach_msg_async_reply_invoke + 344
# 14  libdispatch.dylib                   0x0000000183518c70 _dispatch_main_queue_drain + 756
# 15  libdispatch.dylib                   0x000000018351896c _dispatch_main_queue_callback_4CF + 44
# 16  CoreFoundation                      0x00000001837b2d40 __CFRUNLOOP_IS_SERVICING_THE_MAIN_DISPATCH_QUEUE__ + 16
# 17  CoreFoundation                      0x00000001837707c0 __CFRunLoopRun + 2036
# 18  CoreFoundation                      0x000000018376f878 CFRunLoopRunSpecific + 612
# 19  HIToolbox                           0x000000018ce4ffa0 RunCurrentEventLoopInMode + 292
# 20  HIToolbox                           0x000000018ce4fc30 ReceiveNextEventCommon + 236
# 21  HIToolbox                           0x000000018ce4fb2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 22  AppKit                              0x00000001869f5838 _DPSNextEvent + 632
# 23  AppKit                              0x00000001869f49c8 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 24  cv2.abi3.so                         0x0000000164706e04 cvWaitKey + 560
# 25  cv2.abi3.so                         0x0000000164700e64 _ZN2cv9waitKeyExEi + 168
# 26  cv2.abi3.so                         0x0000000164700f5c _ZN2cv7waitKeyEi + 48
# 27  cv2.abi3.so                         0x0000000163cc98f0 _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 28  python3.10                          0x0000000104579648 cfunction_call + 60
# 29  python3.10                          0x0000000104637334 _PyEval_EvalFrameDefault + 59080
# 30  python3.10                          0x0000000104626f60 _PyEval_Vector + 532
# 31  python3.10                          0x0000000104621a14 builtin_exec + 308
# 32  python3.10                          0x000000010457a44c cfunction_vectorcall_FASTCALL + 88
# 33  python3.10                          0x0000000104651a48 call_function + 148
# 34  python3.10                          0x000000010462a95c _PyEval_EvalFrameDefault + 7408
# 35  python3.10                          0x0000000104535e64 gen_send_ex2 + 220
# 36  python3.10                          0x0000000104635858 _PyEval_EvalFrameDefault + 52204
# 37  python3.10                          0x0000000104535e64 gen_send_ex2 + 220
# 38  python3.10                          0x0000000104635858 _PyEval_EvalFrameDefault + 52204
# 39  python3.10                          0x0000000104535e64 gen_send_ex2 + 220
# 40  python3.10                          0x0000000104536488 gen_send + 52
# 41  python3.10                          0x000000010452a908 method_vectorcall_O + 112
# 42  python3.10                          0x00000001046311c4 _PyEval_EvalFrameDefault + 34136
# 43  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 44  python3.10                          0x0000000104651a48 call_function + 148
# 45  python3.10                          0x000000010462a95c _PyEval_EvalFrameDefault + 7408
# 46  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 47  python3.10                          0x00000001046311c4 _PyEval_EvalFrameDefault + 34136
# 48  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 49  python3.10                          0x00000001045203b0 method_vectorcall + 124
# 50  python3.10                          0x0000000104630e2c _PyEval_EvalFrameDefault + 33216
# 51  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 52  python3.10                          0x00000001045203b0 method_vectorcall + 124
# 53  python3.10                          0x0000000104651a48 call_function + 148
# 54  python3.10                          0x000000010462a86c _PyEval_EvalFrameDefault + 7168
# 55  python3.10                          0x0000000104535e64 gen_send_ex2 + 220
# 56  python3.10                          0x0000000104635858 _PyEval_EvalFrameDefault + 52204
# 57  python3.10                          0x0000000104535e64 gen_send_ex2 + 220
# 58  python3.10                          0x0000000104635858 _PyEval_EvalFrameDefault + 52204
# 59  python3.10                          0x0000000104535e64 gen_send_ex2 + 220
# 60  python3.10                          0x0000000104635858 _PyEval_EvalFrameDefault + 52204
# 61  python3.10                          0x0000000104535e64 gen_send_ex2 + 220
# 62  python3.10                          0x0000000104635858 _PyEval_EvalFrameDefault + 52204
# 63  python3.10                          0x0000000104535e64 gen_send_ex2 + 220
# 64  _asyncio.cpython-310-darwin.so      0x00000001061dc54c task_step_impl + 440
# 65  _asyncio.cpython-310-darwin.so      0x00000001061dc304 task_step + 68
# 66  _asyncio.cpython-310-darwin.so      0x00000001061dce08 task_wakeup + 136
# 67  python3.10                          0x000000010457a13c cfunction_vectorcall_O + 100
# 68  python3.10                          0x000000010466a2cc _PyObject_VectorcallTstate.4686 + 88
# 69  python3.10                          0x000000010466a190 context_run + 92
# 70  python3.10                          0x000000010457a39c cfunction_vectorcall_FASTCALL_KEYWORDS + 84
# 71  python3.10                          0x000000010463467c _PyEval_EvalFrameDefault + 47632
# 72  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 73  python3.10                          0x00000001046311c4 _PyEval_EvalFrameDefault + 34136
# 74  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 75  python3.10                          0x00000001046311c4 _PyEval_EvalFrameDefault + 34136
# 76  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 77  python3.10                          0x00000001046311c4 _PyEval_EvalFrameDefault + 34136
# 78  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 79  python3.10                          0x00000001046311c4 _PyEval_EvalFrameDefault + 34136
# 80  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 81  python3.10                          0x00000001046311c4 _PyEval_EvalFrameDefault + 34136
# 82  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 83  python3.10                          0x00000001045203b0 method_vectorcall + 124
# 84  python3.10                          0x000000010463296c _PyEval_EvalFrameDefault + 40192
# 85  python3.10                          0x0000000104626f60 _PyEval_Vector + 532
# 86  python3.10                          0x0000000104621a14 builtin_exec + 308
# 87  python3.10                          0x000000010457a44c cfunction_vectorcall_FASTCALL + 88
# 88  python3.10                          0x0000000104651a48 call_function + 148
# 89  python3.10                          0x000000010462a95c _PyEval_EvalFrameDefault + 7408
# 90  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 91  python3.10                          0x0000000104651a48 call_function + 148
# 92  python3.10                          0x000000010462a95c _PyEval_EvalFrameDefault + 7408
# 93  python3.10                          0x000000010451bcf4 _PyFunction_Vectorcall + 548
# 94  python3.10                          0x00000001046c2f38 pymain_run_module + 212
# 95  python3.10                          0x00000001046c2920 pymain_run_python + 188
# 96  python3.10                          0x00000001046c280c Py_RunMain + 40
# 97  python3.10                          0x00000001044bbb58 main + 56
# 98  dyld                                0x0000000183367e50 start + 2544

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import load_img,img_to_array

# %%
 df.iloc[:,1].values
